# %%
import pandas as pd

# %%
poverty_df = pd.read_csv('Resources/poverty_rates.csv')

# %%
poverty_df.head()
# Out:
#                id     Geographic Area Name  \
# 0  310M400US10100  Aberdeen, SD Micro Area
# 1  310M400US10140  Aberdeen, WA Micro Area
# 2  310M400US10180   Abilene, TX Metro Area
# 3  310M400US10220       Ada, OK Micro Area
# 4  310M400US10260  Adjuntas, PR Micro Area
#
#    Estimate!!Total!!Population for whom poverty status is determined  \
# 0                                            41450.0
# 1                                            68852.0
# 2                                           156492.0
# 3                                            36923.0
# 4                                            18125.0
#
#    Margin of Error!!Total MOE!!Population for whom poverty status is determined  \
# 0                                              202.0
# 1                                              420.0
# 2                                              773.0
# 3                                              307.0
# 4                                               41.0
#
# ...

# %%
poverty_df['Geographic Area Name'] = poverty_df['Geographic Area Name'].str.replace(r'(\sMicro Area|Metro Area)', "", regex=True)
location = poverty_df[['Geographic Area Name']]
location
# Out:
#     Geographic Area Name
# 0           Aberdeen, SD
# 1           Aberdeen, WA
# 2           Abilene, TX
# 3                Ada, OK
# 4           Adjuntas, PR
# ..                   ...
# 941       Yuba City, CA
# 942            Yuma, AZ
# 943       Zanesville, OH
# 944           Zapata, TX
# 945        United States
#
# [946 rows x 1 columns]
