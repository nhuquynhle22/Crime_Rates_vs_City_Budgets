# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
crime_df = pd.read_csv('Resources/clean_crime_rates.csv')

# %%
age = crime_df['Age'].value_counts()
age
# Out:
# 22          440
# 21          424
# 24          401
# 27          392
# 23          390
#            ...
# 3 days        1
# 6 months      1
# 8 months      1
# 46/53         1
# 3 months      1
# Name: Age, Length: 110, dtype: int64

# %%
crime_df["Age"].value_counts().head(35).plot(kind="bar", title = "Age Count")
plt.xticks(rotation=85)
plt.xlabel('Age')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
gender = crime_df['Gender'].value_counts()
gender
# Out:
# Male           11390
# Female          1217
# Transgender        9
# Name: Gender, dtype: int64

# %%
ethnicity = crime_df['Ethnicity'].value_counts()
ethnicity
# Out:
# European-American/White    5320
# African-American/Black     3432
# Hispanic/Latino            2741
# Race unspecified            657
# Asian/Pacific Islander      326
# Native American/Alaskan      85
# Middle Eastern               25
# Name: Ethnicity, dtype: int64

# %%
crime_df['Ethnicity'].value_counts().plot(kind='barh',title = "Ethniticty Count" ,figsize=(14,8), legend= 1)
plt.xlabel('Count')
plt.ylabel('Ethnicity')
plt.grid(axis='y')

# %%
cause = crime_df['Cause of death'].value_counts()
cause
# Out:
# Gunshot                              9097
# Vehicle                              2421
# Tasered                               462
# Asphyxiated/Restrained                150
# Medical emergency                     127
# Beaten/Bludgeoned with instrument      95
# Drowned                                85
# Undetermined                           51
# Fell from a height                     37
# Other                                  37
# Drug overdose                          34
# Stabbed                                19
# Chemical agent/Pepper spray            15
# Burned/Smoke inhalation                12
# Name: Cause of death, dtype: int64

# %%
crime_df['Cause of death'].value_counts().plot(kind='barh',title = "Causes of Death Count" ,figsize=(14,8), legend= 1)
plt.xlabel('Count')
plt.ylabel('Cause of Death')
plt.grid(axis='y')

# %%
plt.savefig('cause of death.png')

# %%
intentions = crime_df['Intentional Use of Force (Developing)'].value_counts()
intentions
# Out:
# Intentional use of deadly force    8035
# Vehicle/Pursuit                    2251
# Suicide                            1042
# Yes                                 814
# No                                  312
# Pursuit                             134
# Undetermined                         28
# Vehicle                              24
# Np                                    1
# Unknown                               1
# Name: Intentional Use of Force (Developing), dtype: int64

# %%
crime_df['Intentional Use of Force (Developing)'].value_counts().plot(kind='barh',title = "Intentions Count" ,figsize=(14,8), legend= 1)
plt.xlabel('Count')
plt.ylabel('Type of Force')
plt.grid(axis='y')

# %%
location = crime_df['Location of death (state)'].value_counts()
location
# Out:
# CA    4584
# FL    1736
# GA    1075
# IL    1046
# PA     924
# NY     647
# AL     635
# CO     625
# WA     619
# NV     378
# MN     320
# NH      53
# Name: Location of death (state), dtype: int64

# %%
crime_df['Location of death (state)'].value_counts().plot(kind='barh',title = "State Counts" ,figsize=(15,8), legend= 1)
plt.xlabel('Count')
plt.ylabel('State')
plt.grid(axis='y')
