# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
crime_df = pd.read_csv('Resources/clean_crime_rates.csv')

# %%
age = crime_df['Age'].value_counts()
age
# Out:
# 22           920
# 25           896
# 24           864
# 27           851
# 23           849
#             ...
# 7 months       1
# 9 months       1
# 6 months       1
# 18 months      1
# 70s            1
# Name: Age, Length: 117, dtype: int64

# %%
crime_df["Age"].value_counts().head(35).plot(kind="bar", title = "Age Count")
plt.xticks(rotation=85)
plt.xlabel('Age')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
gender = crime_df['Gender'].value_counts()
gender
# Out:
# Male           25789
# Female          2713
# Transgender       19
# Name: Gender, dtype: int64

# %%
ethnicity = crime_df['Ethnicity'].value_counts()
ethnicity
# Out:
# European-American/White    13693
# African-American/Black      7776
# Hispanic/Latino             4714
# Race unspecified            1407
# Asian/Pacific Islander       532
# Native American/Alaskan      277
# Middle Eastern                49
# Name: Ethnicity, dtype: int64

# %%
crime_df['Ethnicity'].value_counts().plot(kind='barh',title = "Ethniticty Count" ,figsize=(14,8), legend= 1)
plt.xlabel('Count')
plt.ylabel('Ethnicity')
plt.grid(axis='y')

# %%
cause = crime_df['Cause of death'].value_counts()
cause
# Out:
# Gunshot                              20292
# Vehicle                               5871
# Tasered                                917
# Medical emergency                      382
# Asphyxiated/Restrained                 278
# Drug overdose                          178
# Drowned                                176
# Beaten/Bludgeoned with instrument      175
# Undetermined                           103
# Fell from a height                      75
# Other                                   56
# Stabbed                                 48
# Chemical agent/Pepper spray             35
# Burned/Smoke inhalation                 35
# Name: Cause of death, dtype: int64

# %%
crime_df['Cause of death'].value_counts().plot(kind='barh',title = "Causes of Death Count" ,figsize=(14,8), legend= 1)
plt.xlabel('Count')
plt.ylabel('Cause of Death')
plt.grid(axis='y')

# %%
year = crime_df['Date (Year)'].value_counts()
year
# Out:
# 2018    1852
# 2019    1812
# 2013    1784
# 2017    1767
# 2014    1717
# 2015    1608
# 2016    1598
# 2012    1486
# 2011    1408
# 2010    1293
# 2020    1290
# 2006    1269
# 2009    1257
# 2007    1255
# 2008    1210
# 2005    1170
# 2003    1052
# 2004    1036
# 2002     986
# 2001     923
# 2000     848
# Name: Date (Year), dtype: int64

# %%
crime_df["Date (Year)"].value_counts().plot(kind='barh',title = "Occurances from 2000-2018" ,figsize=(14,8), legend= 1)
plt.xlabel('Count')
plt.ylabel('Year')
plt.grid(axis='y')

# %%
intentions = crime_df['Intentional Use of Force (Developing)'].value_counts()
intentions
# Out:
# Intentional use of deadly force    17307
# Vehicle/Pursuit                     5428
# Suicide                             2969
# Yes                                 1659
# No                                   801
# Pursuit                              332
# Vehicle                               74
# Undetermined                          48
# Np                                     1
# Unknown                                1
# Intentional use of force               1
# Name: Intentional Use of Force (Developing), dtype: int64

# %%
crime_df['Intentional Use of Force (Developing)'].value_counts().plot(kind='barh',title = "Intentions Count" ,figsize=(14,8), legend= 1)
plt.xlabel('Count')
plt.ylabel('Type of Force')
plt.grid(axis='y')

# %%
location = crime_df['Location of death (state)'].value_counts()
location
# Out:
# CA    4584
# TX    2527
# FL    1736
# GA    1075
# IL    1046
# OH     941
# PA     924
# MO     881
# MI     841
# AZ     830
# OK     661
# NY     647
# AL     635
# CO     625
# WA     619
# TN     618
# NC     600
# LA     598
# VA     590
# SC     546
# IN     533
# NJ     515
# MD     510
# WI     433
# MS     409
# KS     394
# NM     386
# KY     386
# NV     378
# AR     356
# MN     320
# OR     318
# IA     263
# UT     238
# NE     197
# MA     189
# WV     172
# ID     141
# CT     136
# AK     118
# HI     107
# MT      96
# ME      96
# DC      81
# DE      59
# WY      57
# SD      56
# NH      53
# VT      39
# ND      35
# RI      26
# Name: Location of death (state), dtype: int64

# %%
crime_df['Location of death (state)'].value_counts().plot(kind='barh',title = "State Counts" ,figsize=(15,8), legend= 1)
plt.xlabel('Count')
plt.ylabel('State')
plt.grid(axis='y')
